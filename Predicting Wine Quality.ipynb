# %%
#importing necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Dataset details

# %% [markdown]
# ## importing the dataset

# %%
#importing dataset
wine = pd.read_csv("winequality.csv")
wine.head()
# Out:
#     type  fixed acidity  volatile acidity  citric acid  residual sugar  \
# 0  white            7.0              0.27         0.36            20.7
# 1  white            6.3              0.30         0.34             1.6
# 2  white            8.1              0.28         0.40             6.9
# 3  white            7.2              0.23         0.32             8.5
# 4  white            7.2              0.23         0.32             8.5
#
#    chlorides  free sulfur dioxide  total sulfur dioxide  density    pH  \
# 0      0.045                 45.0                 170.0   1.0010  3.00
# 1      0.049                 14.0                 132.0   0.9940  3.30
# 2      0.050                 30.0                  97.0   0.9951  3.26
# 3      0.058                 47.0                 186.0   0.9956  3.19
# 4      0.058                 47.0                 186.0   0.9956  3.19
#
#    sulphates  alcohol  quality
# 0       0.45      8.8        6
# 1       0.49      9.5        6
# ...

# %%
#copying the original data
data = wine.copy()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6497 entries, 0 to 6496
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   type                  6497 non-null   object
#  1   fixed acidity         6487 non-null   float64
#  2   volatile acidity      6489 non-null   float64
#  3   citric acid           6494 non-null   float64
#  4   residual sugar        6495 non-null   float64
#  5   chlorides             6495 non-null   float64
#  6   free sulfur dioxide   6497 non-null   float64
#  7   total sulfur dioxide  6497 non-null   float64
#  8   density               6497 non-null   float64
#  9   pH                    6488 non-null   float64
#  10  sulphates             6493 non-null   float64
#  11  alcohol               6497 non-null   float64
#  12  quality               6497 non-null   int64
# dtypes: float64(11), int64(1), object(1)
# memory usage: 660.0+ KB

# %%
#renaming the columns
data.rename(columns={'fixed acidity':'fixed_acidity','volatile acidity':'volatile_acidity','citric acid':'citric_acid',
                     'residual sugar':'residual_sugar','free sulfur dioxide':'free_sulfur_dioxide',
                     'total sulfur dioxide':'total_sulfur_dioxide'},inplace=True)

# %%
#checking missing values
data.isna().sum()
# Out:
# type                     0
# fixed_acidity           10
# volatile_acidity         8
# citric_acid              3
# residual_sugar           2
# chlorides                2
# free_sulfur_dioxide      0
# total_sulfur_dioxide     0
# density                  0
# pH                       9
# sulphates                4
# alcohol                  0
# quality                  0
# dtype: int64

# %%
data.describe()
# Out:
#        fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# count    6487.000000       6489.000000  6494.000000     6495.000000
# mean        7.216579          0.339691     0.318722        5.444326
# std         1.296750          0.164649     0.145265        4.758125
# min         3.800000          0.080000     0.000000        0.600000
# 25%         6.400000          0.230000     0.250000        1.800000
# 50%         7.000000          0.290000     0.310000        3.000000
# 75%         7.700000          0.400000     0.390000        8.100000
# max        15.900000          1.580000     1.660000       65.800000
#
#          chlorides  free_sulfur_dioxide  total_sulfur_dioxide      density  \
# count  6495.000000          6497.000000           6497.000000  6497.000000
# mean      0.056042            30.525319            115.744574     0.994697
# std       0.035036            17.749400             56.521855     0.002999
# ...

# %% [markdown]
# ## Imputation of Missing values

# %%
#null values are filled with median 
data.fixed_acidity.fillna(data.fixed_acidity.median(),inplace=True)
data.volatile_acidity.fillna(data.volatile_acidity.median(),inplace=True)
data.citric_acid.fillna(data.citric_acid.median(),inplace=True)
data.residual_sugar.fillna(data.residual_sugar.median(),inplace=True)                             
data.chlorides.fillna(data.chlorides.median(),inplace=True)
data.pH.fillna(data.pH.median(),inplace=True)
data.sulphates.fillna(data.sulphates.median(),inplace=True)

# %%
#checking number of unique values
data.nunique()
# Out:
# type                      2
# fixed_acidity           106
# volatile_acidity        187
# citric_acid              89
# residual_sugar          316
# chlorides               214
# free_sulfur_dioxide     135
# total_sulfur_dioxide    276
# density                 998
# pH                      108
# sulphates               111
# alcohol                 111
# quality                   7
# dtype: int64

# %% [markdown]
# # Exploratory data analysis (EDA)

# %% [markdown]
# ## EDA of Variable

# %%
#EDA of variables
for i in data.columns[1:-1]:
    print('Variable_Name : ',i.upper())
    fig, axes = plt.subplots(1,2,figsize=(15,5))
    axes[0].set_title('Distribution')
    data[i].hist(ax=axes[0])
    axes[1].set_title('Checking outliers')
    sns.boxplot(data[i],ax=axes[1])
    plt.show()
# Out:
# Variable_Name :  FIXED_ACIDITY
# Variable_Name :  VOLATILE_ACIDITY
# Variable_Name :  CITRIC_ACID
# Variable_Name :  RESIDUAL_SUGAR
# Variable_Name :  CHLORIDES
# Variable_Name :  FREE_SULFUR_DIOXIDE
# Variable_Name :  TOTAL_SULFUR_DIOXIDE
# Variable_Name :  DENSITY
# Variable_Name :  PH
# Variable_Name :  SULPHATES
# Variable_Name :  ALCOHOL

# %%
#visualizing categorical variables
sns.countplot(data.type)
# Out:
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
sns.countplot(data.quality)
# Out:
# <AxesSubplot:xlabel='quality', ylabel='count'>

# %%
#checking corelation
plt.figure(figsize=(15,6))
sns.heatmap(data.corr(),annot=True,cmap='RdBu')
# Out:
# <AxesSubplot:>

# %% [markdown]
# The variables Total sulphur dioxide and free sulfur dioxide are 72% positively corelated

# %%
#visualizing how the type variable is related to input variables
for i in data.columns[1:-1]:
    plt.figure(figsize=(15,6))
    sns.boxplot(x=data.type,y=data[i])
    plt.title('Relationship b/w {} and type'.format(i))
    plt.show()

# %%
#visualizing how the output is related to input variables
for i in data.columns[1:-1]:
    plt.figure(figsize=(15,6))
    sns.boxplot(x=data.quality,y=data[i])
    plt.title('Relationship b/w {} and quality'.format(i))
    plt.show()

# %%
pd.crosstab(data.quality,data.type)
# Out:
# type     red  white
# quality
# 3         10     20
# 4         53    163
# 5        681   1457
# 6        638   2198
# 7        199    880
# 8         18    175
# 9          0      5

# %%
#one hot encoding the type variable
data.type.replace({'red':0,'white':1},inplace=True)

# %%
#splitting the data into input and output
x = data.drop('quality',axis=1)
y = data.quality
print('Shape of X = {}, Y = {}'.format(x.shape,y.shape))
# Out:
# Shape of X = (6497, 12), Y = (6497,)

# %% [markdown]
# Since output variable distribution is uneven. Over sampling technique is used

# %% [markdown]
# ## handling the unbalanced data

# %%
#importing the libraries
from collections import Counter
from imblearn.over_sampling import RandomOverSampler

#initializing the over sampling
sampler = RandomOverSampler()

#Over sampled data
x1, y1 = sampler.fit_resample(x,y)

print('Actual y_train count :',Counter(y))
print('y_train After Over Sampling :',Counter(y1))
# Out:
# Actual y_train count : Counter({6: 2836, 5: 2138, 7: 1079, 4: 216, 8: 193, 3: 30, 9: 5})
# y_train After Over Sampling : Counter({6: 2836, 5: 2836, 7: 2836, 8: 2836, 4: 2836, 3: 2836, 9: 2836})

# %% [markdown]
# # Feature Selection

# %%
#Checking for feature importance using random forest feature importance
#importing libraries
from sklearn.ensemble import RandomForestClassifier

#initializing the model
rand = RandomForestClassifier()

#fitting the model
rand.fit(x1,y1)

#plotting frature importance
plt.title('Random Forest Feature Importance')
sns.barplot(x=rand.feature_importances_,y=x1.columns,color='Blue')
plt.show()

# %%
#Checking for feature importance using Decision tree feature importance
#importing libraries
from sklearn.tree import DecisionTreeClassifier

#initializing the model
deci = DecisionTreeClassifier()

#fitting the model
deci.fit(x1,y1)

#plotting frature importance
plt.title('CART feature importance')
sns.barplot(x=deci.feature_importances_,y=x1.columns,color='Blue')
plt.show()

# %%
#from above graph and corelation graph type and free sulfer dioxide variable is removed
#splitting the data into train and test
x1.drop(['type','free_sulfur_dioxide'],axis=1,inplace=True)

from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x1,y1,test_size=0.2,random_state=2)
print('Shape of Splitting:')
print('x_train = {}\nx_test = {}\n\ny_train = {}\ny_test = {}'.format(x_train.shape,x_test.shape,y_train.shape,y_test.shape))
# Out:
# Shape of Splitting:
# x_train = (15881, 10)
# x_test = (3971, 10)
#
# y_train = (15881,)
# y_test = (3971,)

# %% [markdown]
# # Building the Model

# %% [markdown]
# ## Building the logistic regression model

# %%
#importing the model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report, plot_confusion_matrix

#initializing th model
logis = LogisticRegression(solver='liblinear')

#fitting the model and predicting for test data
pred_logis = logis.fit(x_train,y_train).predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=logis, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_logis,y_true=y_test))

#calculating accuracy
acc_logis = accuracy_score(y_test,pred_logis)
# Out:
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       0.45      0.46      0.46       564
#            4       0.35      0.37      0.36       548
#            5       0.34      0.34      0.34       554
#            6       0.25      0.16      0.20       576
#            7       0.38      0.19      0.25       603
#            8       0.40      0.45      0.42       549
#            9       0.61      1.00      0.76       577
#
#     accuracy                           0.43      3971
#    macro avg       0.40      0.43      0.40      3971
# weighted avg       0.40      0.43      0.40      3971

# %%
#checking hyper-parameters
logis.get_params().keys()
# Out:
# dict_keys(['C', 'class_weight', 'dual', 'fit_intercept', 'intercept_scaling', 'l1_ratio', 'max_iter', 'multi_class', 'n_jobs', 'penalty', 'random_state', 'solver', 'tol', 'verbose', 'warm_start'])

# %%
#Hyper parameter tuning using GridSearchCV
from sklearn.model_selection import GridSearchCV

#hyper parameters are
params = {'solver' : ['liblinear'],
          'penalty' : ['l2','l1'],
          'C' : [100, 10, 1.0]
         }

#initializing the grid
grid = GridSearchCV(estimator=logis,param_grid=params,cv=5,verbose=3,n_jobs=-1)

#fitting the model
grid.fit(x_train,y_train)

print('Best Score : ',grid.best_score_)
print('Best parameters : ',grid.best_params_,'\n')

#predicting for test data
pred_logis = grid.predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=grid, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_logis,y_true=y_test))

#calculating accuracy
acc_logis = accuracy_score(y_test,pred_logis)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# Best Score :  0.44833447504061386
# Best parameters :  {'C': 10, 'penalty': 'l1', 'solver': 'liblinear'}
#
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       0.45      0.49      0.47       564
#            4       0.36      0.35      0.36       548
#            5       0.32      0.36      0.34       554
#            6       0.26      0.15      0.19       576
#            7       0.42      0.26      0.32       603
#            8       0.36      0.49      0.42       549
#            9       0.77      1.00      0.87       577
#
#     accuracy                           0.44      3971
#    macro avg       0.42      0.44      0.42      3971
# weighted avg       0.42      0.44      0.42      3971

# %% [markdown]
# ## Building the KNN model

# %%
#importing libraries
from sklearn.neighbors import KNeighborsClassifier

#initializing th model
knn = KNeighborsClassifier()

#fitting the model and predicting for test data
pred_knn = knn.fit(x_train,y_train).predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=knn, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_knn,y_true=y_test))

#calculating accuracy
acc_knn = accuracy_score(y_test,pred_knn)
# Out:
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       0.98      1.00      0.99       564
#            4       0.84      1.00      0.91       548
#            5       0.59      0.59      0.59       554
#            6       0.51      0.34      0.41       576
#            7       0.72      0.77      0.75       603
#            8       0.92      1.00      0.96       549
#            9       1.00      1.00      1.00       577
#
#     accuracy                           0.81      3971
#    macro avg       0.80      0.81      0.80      3971
# weighted avg       0.80      0.81      0.80      3971

# %%
#hyper-parameters
knn.get_params().keys()
# Out:
# dict_keys(['algorithm', 'leaf_size', 'metric', 'metric_params', 'n_jobs', 'n_neighbors', 'p', 'weights'])

# %%
#hyper parameters are
params = {'n_neighbors' : range(2,15),
          'leaf_size' : range(1,15)
         }

#initializing the grid
grid = GridSearchCV(estimator=knn,param_grid=params,cv=3,verbose=3,n_jobs=-1)

#fitting the model
grid.fit(x_train,y_train)

print('Best Score : ',grid.best_score_)
print('Best parameters : ',grid.best_params_,'\n')

#predicting for test data
pred_knn = grid.predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=grid, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_knn,y_true=y_test))

#calculating accuracy
acc_knn = accuracy_score(y_test,pred_knn)
# Out:
# Fitting 3 folds for each of 342 candidates, totalling 1026 fits
# Best Score :  0.830426754198669
# Best parameters :  {'leaf_size': 1, 'n_neighbors': 2}
#
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       0.99      1.00      0.99       564
#            4       0.90      1.00      0.95       548
#            5       0.66      0.80      0.72       554
#            6       0.66      0.44      0.53       576
#            7       0.85      0.83      0.84       603
#            8       0.96      1.00      0.98       549
#            9       1.00      1.00      1.00       577
#
#     accuracy                           0.87      3971
#    macro avg       0.86      0.87      0.86      3971
# weighted avg       0.86      0.87      0.86      3971

# %% [markdown]
# ## Building SVM model

# %%
#importing the libraries
from sklearn.svm import SVC

#initializing th model
svm = SVC()

#fitting the model and predicting for test data
pred_svm = svm.fit(x_train,y_train).predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=svm, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_svm,y_true=y_test))

#calculating accuracy
acc_svm = accuracy_score(y_test,pred_svm)
# Out:
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       0.39      0.40      0.40       564
#            4       0.27      0.25      0.26       548
#            5       0.23      0.35      0.28       554
#            6       0.25      0.00      0.01       576
#            7       0.40      0.03      0.06       603
#            8       0.20      0.13      0.16       549
#            9       0.28      0.81      0.42       577
#
#     accuracy                           0.28      3971
#    macro avg       0.29      0.28      0.23      3971
# weighted avg       0.29      0.28      0.22      3971

# %%
#hyper-parameters
svm.get_params().keys()
# Out:
# dict_keys(['C', 'break_ties', 'cache_size', 'class_weight', 'coef0', 'decision_function_shape', 'degree', 'gamma', 'kernel', 'max_iter', 'probability', 'random_state', 'shrinking', 'tol', 'verbose'])

# %%
#hyper parameters are
params = {'C' : [0.01,0.1,1,10],
          'kernel' : ['linear','rbf']
         }

#initializing the grid
grid = GridSearchCV(estimator=svm,param_grid=params,cv=3,verbose=3,n_jobs=-1)

#fitting the model
grid.fit(x_train,y_train)

print('Best Score : ',grid.best_score_)
print('Best parameters : ',grid.best_params_,'\n')

#predicting for test data
pred_svm = grid.predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=grid, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_svm,y_true=y_test))

#calculating accuracy
acc_svm = accuracy_score(y_test,pred_svm)
# Out:
# Fitting 5 folds for each of 8 candidates, totalling 40 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-77936a9a0494> in <module>
#       8
#       9 #fitting the model
# ---> 10 grid.fit(x_train,y_train)
#      11
#      12 print('Best Score : ',grid.best_score_)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      71                           FutureWarning)
#      72         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 73         return f(**kwargs)
#      74     return inner_f
#      75
#
# ~\anaconda3\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     734                 return results
#     735
# --> 736             self._run_search(evaluate_candidates)
# ...

# %% [markdown]
# ## Building the Adaboost model

# %%
#importing libraries
from sklearn.ensemble import AdaBoostClassifier

#initializing th model
ada = AdaBoostClassifier()

#fitting the model and predicting for test data
pred_ada = ada.fit(x_train,y_train).predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=ada, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_ada,y_true=y_test))

#calculating accuracy
acc_ada = accuracy_score(y_test,pred_ada)
# Out:
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       0.47      0.12      0.19       564
#            4       0.16      0.26      0.20       548
#            5       0.26      0.12      0.17       554
#            6       0.19      0.25      0.21       576
#            7       0.18      0.34      0.23       603
#            8       0.23      0.28      0.25       549
#            9       0.92      0.17      0.29       577
#
#     accuracy                           0.22      3971
#    macro avg       0.34      0.22      0.22      3971
# weighted avg       0.34      0.22      0.22      3971

# %%
#Hyper-parameters
ada.get_params().keys()
# Out:
# dict_keys(['algorithm', 'base_estimator', 'learning_rate', 'n_estimators', 'random_state'])

# %%
#hyper parameters are
params = {'n_estimators' : [100,200,300],
          'learning_rate':[0.001,0.01,0.1]
         }

#initializing the grid
grid = GridSearchCV(estimator=ada,param_grid=params,cv=3,verbose=3,n_jobs=-1)

#fitting the model
grid.fit(x_train,y_train)

print('Best Score : ',grid.best_score_)
print('Best parameters : ',grid.best_params_,'\n')

#predicting for test data
pred_ada = grid.predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=grid, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_ada,y_true=y_test))

#calculating accuracy
acc_ada = accuracy_score(y_test,pred_ada)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# Best Score :  0.3218318273157223
# Best parameters :  {'learning_rate': 0.01, 'n_estimators': 100}
#
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       0.20      0.56      0.29       564
#            4       0.00      0.00      0.00       548
#            5       0.00      0.00      0.00       554
#            6       0.00      0.00      0.00       576
#            7       0.22      0.33      0.26       603
#            8       0.32      0.37      0.34       549
#            9       0.70      1.00      0.82       577
#
#     accuracy                           0.33      3971
#    macro avg       0.20      0.32      0.25      3971
# weighted avg       0.21      0.33      0.25      3971

# %% [markdown]
# ## Building Random Forest Model

# %%
#importing libraries
from sklearn.ensemble import RandomForestClassifier

#initializing the model
rand = RandomForestClassifier(n_estimators=500)

#fitting the model and predicting for test data
pred_rand = rand.fit(x_train,y_train).predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=rand, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_rand,y_true=y_test))

#calculating accuracy
acc_rand = accuracy_score(y_test,pred_rand)
# Out:
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00       564
#            4       0.99      1.00      0.99       548
#            5       0.80      0.86      0.83       554
#            6       0.79      0.68      0.73       576
#            7       0.89      0.93      0.91       603
#            8       0.99      1.00      1.00       549
#            9       1.00      1.00      1.00       577
#
#     accuracy                           0.92      3971
#    macro avg       0.92      0.92      0.92      3971
# weighted avg       0.92      0.92      0.92      3971

# %%
rand.get_params().keys()
# Out:
# dict_keys(['bootstrap', 'ccp_alpha', 'class_weight', 'criterion', 'max_depth', 'max_features', 'max_leaf_nodes', 'max_samples', 'min_impurity_decrease', 'min_impurity_split', 'min_samples_leaf', 'min_samples_split', 'min_weight_fraction_leaf', 'n_estimators', 'n_jobs', 'oob_score', 'random_state', 'verbose', 'warm_start'])

# %%
#hyper parameters are
params = {'n_estimators' : [300,400,500],
          'max_depth':[20,30,40],
          'min_samples_leaf':[10,15,20]
         }

#initializing the grid
grid = GridSearchCV(estimator=rand,param_grid=params,cv=3,verbose=3,n_jobs=-1)

#fitting the model
grid.fit(x_train,y_train)

print('Best Score : ',grid.best_score_)
print('Best parameters : ',grid.best_params_,'\n')

#predicting for test data
pred_rand = grid.predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=grid, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_rand,y_true=y_test))

#calculating accuracy
acc_rand = accuracy_score(y_test,pred_rand)
# Out:
# Fitting 3 folds for each of 27 candidates, totalling 81 fits
# Best Score :  0.8440276750081539
# Best parameters :  {'max_depth': 40, 'min_samples_leaf': 10, 'n_estimators': 400}
#
# CONFUSION MATRIX :

# %% [markdown]
# ## Building the XGBoost model

# %%
#importing libraries
from xgboost import XGBClassifier

#initializing the model
xgb = XGBClassifier(eval_metric='merror',n_estimators=650,max_depth=15)

#fitting the model and predicting for test data
pred_xgb = xgb.fit(x_train,y_train).predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=xgb, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_xgb,y_true=y_test))

#calculating accuracy
acc_xgb = accuracy_score(y_test,pred_xgb)
acc_xgb
# Out:
# CONFUSION MATRIX :
# REPORT:                precision    recall  f1-score   support
#
#            3       1.00      1.00      1.00       564
#            4       0.97      1.00      0.99       548
#            5       0.80      0.83      0.82       554
#            6       0.80      0.68      0.73       576
#            7       0.89      0.96      0.93       603
#            8       0.99      1.00      0.99       549
#            9       1.00      1.00      1.00       577
#
#     accuracy                           0.92      3971
#    macro avg       0.92      0.92      0.92      3971
# weighted avg       0.92      0.92      0.92      3971
# 0.9236968018131453

# %%
xgb.get_params().keys()
# Out:
# dict_keys(['objective', 'use_label_encoder', 'base_score', 'booster', 'colsample_bylevel', 'colsample_bynode', 'colsample_bytree', 'gamma', 'gpu_id', 'importance_type', 'interaction_constraints', 'learning_rate', 'max_delta_step', 'max_depth', 'min_child_weight', 'missing', 'monotone_constraints', 'n_estimators', 'n_jobs', 'num_parallel_tree', 'random_state', 'reg_alpha', 'reg_lambda', 'scale_pos_weight', 'subsample', 'tree_method', 'validate_parameters', 'verbosity', 'eval_metric'])

# %%
#Hyper parameter tuning using GridSearchCV
from sklearn.model_selection import GridSearchCV

#hyper parameters are
params = {'n_estimators' : [600,650,700],
          'max_depth':[10,15,20]
         }

#initializing the grid
grid = GridSearchCV(estimator=xgb,param_grid=params,cv=3,verbose=3,n_jobs=-1)

#fitting the model
grid.fit(x_train,y_train)

print('Best Score : ',grid.best_score_)
print('Best parameters : ',grid.best_params_,'\n')

#predicting for test data
pred_xgb = grid.predict(x_test)

#plotting the confusion matrix
print('CONFUSION MATRIX : ')
fig, ax = plt.subplots(figsize=(15, 8))
plot_confusion_matrix(estimator=grid, X=x_test, y_true=y_test,cmap='YlGn_r',ax=ax)
plt.show()

#printing the classification report
print('REPORT: ',classification_report(y_pred=pred_xgb,y_true=y_test))

#calculating accuracy
acc_xgb = accuracy_score(y_test,pred_xgb)
# Out:
# Fitting 3 folds for each of 9 candidates, totalling 27 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-25-9eea502b7324> in <module>
#      11
#      12 #fitting the model
# ---> 13 grid.fit(x_train,y_train)
#      14
#      15 print('Best Score : ',grid.best_score_)
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
# ...

# %%
#consolidating the result
index = ['Logistic Regression','KNN','SVM','Adaboost','Random Forest','XGB']
res = pd.DataFrame(columns=['Algorithm','Accuracy'])
acc = [acc_logis,acc_knn,acc_svm,acc_ada,acc_rand,acc_xgb]

res.Algorithm = index; res.Accuracy = acc
res

# %% [markdown]
# ## Final Model

# %% [markdown]
# XGBoost model is considered as final model as it gives better accuracy

# %%
#importing libraries
from xgboost import XGBClassifier

#initializing the model
xgb = XGBClassifier(eval_metric='merror',n_estimators=650,max_depth=15)

#fitting the model
xgb.fit(x1,y1)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric='merror',
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=15, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=650, n_jobs=4,
#               num_parallel_tree=1, objective='multi:softprob', random_state=0,
#               reg_alpha=0, reg_lambda=1, scale_pos_weight=None, subsample=1,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
#pickling the files
import pickle
pickle_out = open('classifier.pkl','wb')
pickle.dump(xgb,pickle_out)
pickle_out.close()

# %% [markdown]
# ## Testing Model

# %%
#loading model
import pickle
model = pickle.load(open('classifier.pkl','rb'))

# %%
inpu = [[7.0,0.27,0.36,20.7,0.045,170,1.001,3.00,0.45,8.8]]
x = pd.DataFrame(inpu,columns=["fixed_acidity","volatile_acidity","citric_acid","residual_sugar","chlorides","total_sulfur_dioxide","density","pH","sulphates","alcohol"])
x
model.predict(x)
# Out:
# array([6])

# %%
data[data.quality==8]
# Out:
#       type  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 17       1            7.0              0.66         0.48             1.2
# 20       1            6.2              0.66         0.48             1.2
# 22       1            6.8              0.26         0.42             1.7
# 68       1            6.7              0.23         0.31             2.1
# 74       1            6.7              0.23         0.31             2.1
# ...    ...            ...               ...          ...             ...
# 6100     0            8.6              0.42         0.39             1.8
# 6167     0            5.5              0.49         0.03             1.8
# 6301     0            7.2              0.33         0.33             1.7
# 6347     0            7.2              0.38         0.31             2.0
# 6447     0            7.4              0.36         0.30             1.8
#
#       chlorides  free_sulfur_dioxide  total_sulfur_dioxide  density    pH  \
# ...
